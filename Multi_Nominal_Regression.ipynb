# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('/content/auto-mpg_without nan.csv')

# %%
data.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0  18.0          8         307.0         130    3504          12.0  1970
# 1  15.0          8         350.0         165    3693          11.5  1970
# 2  18.0          8         318.0         150    3436          11.0  1970
# 3  16.0          8         304.0         150    3433          12.0  1970
# 4  17.0          8         302.0         140    3449          10.5  1970
#
#   origin                       name
# 0    USA  chevrolet chevelle malibu
# 1    USA          buick skylark 320
# 2    USA         plymouth satellite
# 3    USA              amc rebel sst
# 4    USA                ford torino

# %%
# Split Data into X , Y

# %%
# Drop non important columns
data.drop(columns = ['name'],inplace =True)

# %%
# Convert(fix) categorical columns into numerical

# %%
data['origin'] = data['origin'].astype('category')
data['origin'] = data['origin'].cat.codes

# %%
data.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0  18.0          8         307.0         130    3504          12.0  1970
# 1  15.0          8         350.0         165    3693          11.5  1970
# 2  18.0          8         318.0         150    3436          11.0  1970
# 3  16.0          8         304.0         150    3433          12.0  1970
# 4  17.0          8         302.0         140    3449          10.5  1970
#
#    origin
# 0       2
# 1       2
# 2       2
# 3       2
# 4       2

# %%
x = data.iloc[: , 1:]
y = data.iloc[: , 0:1]
print(x.head)
print(y.head)
# Out:
# <bound method NDFrame.head of      cylinders  displacement  horsepower  weight  acceleration  year  origin
# 0            8         307.0         130    3504          12.0  1970       2
# 1            8         350.0         165    3693          11.5  1970       2
# 2            8         318.0         150    3436          11.0  1970       2
# 3            8         304.0         150    3433          12.0  1970       2
# 4            8         302.0         140    3449          10.5  1970       2
# ..         ...           ...         ...     ...           ...   ...     ...
# 387          4         140.0          86    2790          15.6  1982       2
# 388          4          97.0          52    2130          24.6  1982       0
# 389          4         135.0          84    2295          11.6  1982       2
# 390          4         120.0          79    2625          18.6  1982       2
# 391          4         119.0          82    2720          19.4  1982       2
#
# [392 rows x 7 columns]>
# <bound method NDFrame.head of       mpg
# 0    18.0
# 1    15.0
# 2    18.0
# 3    16.0
# 4    17.0
# ..    ...
# 387  27.0
# 388  44.0
# 389  32.0
# 390  28.0
# 391  31.0
#
# [392 rows x 1 columns]>

# %%
# Train Test Split
from sklearn.model_selection import train_test_split

# %%
x_train , x_test , y_train , y_test =train_test_split(x,y , test_size=0.2 , random_state=42)

# %%
# Build a model
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(x_train , y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
# Mean Squared Error
from sklearn.metrics import mean_squared_error

# %%
mse = mean_squared_error(y_test , y_pred)
mse
# Out:
# 10.594285130533283

# %%
# R2 Score

from sklearn.metrics import r2_score

# %%
r2_score(y_test , y_pred)
# Out:
# 0.7924340895411519

# %%
data['origin'] = data['origin'].astype('category')
data['origin'] = data['origin'].cat.codes
